# %%
import pandas as pd

# %%
a = '''n_way: 3
n_shots: 1
n_query: 1
acc=0.3365 ± 0.1193 loss=3.5870

n_way: 3
n_shots: 1
n_query: 5
acc=0.3399 ± 0.0526 loss=3.6068

n_way: 3
n_shots: 1
n_query: 20
acc=0.3372 ± 0.0273 loss=3.6455

n_way: 3
n_shots: 3
n_query: 1
acc=0.3365 ± 0.1184 loss=2.6146

n_way: 3
n_shots: 3
n_query: 5
acc=0.3422 ± 0.0532 loss=2.5877

n_way: 3
n_shots: 3
n_query: 20
acc=0.3427 ± 0.0299 loss=2.5672

n_way: 3
n_shots: 5
n_query: 1
acc=0.3457 ± 0.1238 loss=2.0614

n_way: 3
n_shots: 5
n_query: 5
acc=0.3427 ± 0.0545 loss=2.1122

n_way: 3
n_shots: 5
n_query: 20
acc=0.3439 ± 0.0286 loss=2.1300

n_way: 10
n_shots: 1
n_query: 1
acc=0.1047 ± 0.0420 loss=6.3781

n_way: 10
n_shots: 1
n_query: 5
acc=0.1019 ± 0.0185 loss=6.4753

n_way: 10
n_shots: 1
n_query: 20
acc=0.1035 ± 0.0100 loss=6.4957

n_way: 10
n_shots: 3
n_query: 1
acc=0.1062 ± 0.0440 loss=4.9398

n_way: 10
n_shots: 3
n_query: 5
acc=0.1049 ± 0.0185 loss=4.8486

n_way: 10
n_shots: 3
n_query: 20
acc=0.1056 ± 0.0100 loss=4.6929

n_way: 10
n_shots: 5
n_query: 1
acc=0.1074 ± 0.0428 loss=4.0645

n_way: 10
n_shots: 5
n_query: 5
acc=0.1060 ± 0.0180 loss=3.9552

n_way: 10
n_shots: 5
n_query: 20
acc=0.1061 ± 0.0104 loss=3.8499

n_way: 3
n_shots: 10
n_query: 1
acc=0.3401 ± 0.1150 loss=1.5795

n_way: 3
n_shots: 10
n_query: 10
acc=0.3457 ± 0.0412 loss=1.6197

n_way: 3
n_shots: 20
n_query: 1
acc=0.3448 ± 0.1102 loss=1.3091

n_way: 3
n_shots: 20
n_query: 10
acc=0.3485 ± 0.0364 loss=1.3219

n_way: 10
n_shots: 10
n_query: 1
acc=0.1058 ± 0.0395 loss=3.1494

n_way: 10
n_shots: 10
n_query: 10
acc=0.1075 ± 0.0132 loss=3.0157

n_way: 10
n_shots: 20
n_query: 1
acc=0.1119 ± 0.0400 loss=2.608

n_way: 10
n_shots: 20
n_query: 10
acc=0.1085 ± 0.0127 loss=2.5433'''

df = pd.DataFrame([b.split('\n') for b in a.split('\n\n')])
df[0] = df[0].str.extract(r'n_way: (\d+)').astype(int)
df[1] = df[1].str.extract(r'n_shots: (\d+)').astype(int)
df[2] = df[2].str.extract(r'n_query: (\d+)').astype(int)
acc = df[3].str.extractall(r'acc=(\d+\.\d+)').reset_index(level=1, drop=True)
std = df[3].str.extractall(r'± (\d+\.\d+)').reset_index(level=1, drop=True)
loss = df[3].str.extractall(r'loss=(\d+\.\d+)').reset_index(level=1, drop=True)
df[4] = acc.astype(float)
df[5] = std.astype(float)
df[6] = loss.astype(float)
df.columns = ['n_way', 'n_shots', 'n_query', 'acc_std_loss', 'acc', 'std', 'loss']
del df['acc_std_loss']


#for each nway, plot nshot vs acc for each nquery
import matplotlib.pyplot as plt
import seaborn as sns

# set fig grid
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
for i, n_way in enumerate(df['n_way'].unique()):
    sns.lineplot(data=df[df['n_way'] == n_way], x='n_shots', y='acc', hue='n_query', ax=axes[i])
    axes[i].set_title(f'n_way: {n_way}')
    axes[i].set_xlabel('n_shots')
    axes[i].set_ylabel('acc')
    axes[i].legend(title='n_query')
plt.tight_layout()
plt.show()

# %%
# runs[20]
runs[0].__dict__
# Out:
# {'_attrs': {'projectId': '43623038',
#   'id': 'UnVuOnYxOjF1bHhzaWxiOmdyYXBoLWNsaXA6ZWlibC11c2M=',
#   'tags': [],
#   'name': '1ulxsilb',
#   'displayName': 'eval_retweet_cls_1hop_07_03_2026_14_42_31',
#   'sweepName': None,
#   'state': 'failed',
#   'config': {'params': {'root': 'midterm/graph_retweet',
#     'seed': None,
#     'n_hop': 1,
#     'n_way': 3,
#     'device': 'cuda:0',
#     'epochs': 12,
#     'layers': 'S,U,M',
#     'metric': 'Acc',
#     'prefix': 'eval_retweet_cls_1hop',
#     'dataset': 'midterm',
#     'dropout': 0,
#     'emb_dim': 256,
#     'log_dir': 'log',
#     'n_layer': 1,
#     'n_query': 24,
#     'n_shots': 3,
#     'verbose': False,
#     'workers': 10,
#     'all_test': False,
#     'exp_name': 'eval_retweet_cls_1hop_07_03_2026_14_42_31',
#     'gnn_type': 'sage',
#     'csr_split': False,
#     'eval_only': True,
#     'eval_step': 2000,
#     'input_dim': 98,
#     'label_set': None,
#     'max_users': None,
#     'skip_path': False,
#     'state_dir': 'state',
#     'task_name': 'classification',
#     'timestamp': '07_03_2026_14_42_31',
#     'train_cap': None,
#     'zero_shot': False,
#     'batch_size': 5,
#     'bert_cache': 'multi-qa-distilbert-cos-v1',
#     'calc_ranks': False,
#     'eval_epoch': 10,
#     'label_type': 'verified',
#     'max_length': -1,
#     'print_step': 2000,
#     'second_gnn': 'Atten',
#     'force_cache': False,
#     'n_way_upper': -1,
#     'print_epoch': 10,
#     'val_len_cap': 500,
#     'augment_test': False,
#     'augmentation': '',
#     'csv_filename': 'twitter_data.csv',
#     'kg_emb_model': '',
#     'linear_probe': False,
#     'meta_n_layer': 1,
#     'override_log': False,
#     'test_len_cap': 500,
#     'weight_decay': 0.001,
#     'learning_rate': 0.001,
#     'n_query_upper': -1,
#     'n_shots_upper': -1,
#     'no_bn_encoder': False,
#     'shuffle_index': False,
#     'small_dataset': False,
#     'bert_emb_model': 'multi-qa-distilbert-cos-v1',
#     'has_final_back': False,
#     'checkpoint_step': 2000,
#     'dataset_len_cap': 10000,
#     'experiment_type': 'metagraph',
#     'no_bn_metagraph': False,
#     'no_split_labels': True,
#     'checkpoint_epoch': 10,
#     'invalidate_cache': False,
#     'meta_gnn_pos_only': False,
#     'original_features': True,
#     'reset_after_layer': None,
#     'split_train_nodes': False,
#     'facebook_max_posts': None,
#     'fix_datasets_first': False,
#     'classification_only': False,
#     'facebook_target_dim': 768,
#     'facebook_data_source': 'csv',
#     'pretrained_model_run': 'state/pretrain_retweet_nm_1hop_06_03_2026_19_06_04/state_dict',
#     'attention_mask_scheme': 'causal',
#     'facebook_pkl_filename': 'facebook_2022-06-24_2022-06-25_part1.pkl',
#     'text_features_dropout': 0,
#     'zero_label_embeddings': False,
#     'attr_regression_weight': 0,
#     'rel_sample_random_seed': None,
#     'early_stopping_patience': 20,
#     'facebook_edges_filename': 'facebook_2022-06-24_2022-06-25_part1_edges.csv',
#     'facebook_text_emb_model': '',
#     'ignore_label_embeddings': True,
#     'facebook_embeddings_path': '',
#     'facebook_filter_to_uk_ru': True,
#     'facebook_source_pkl_path': '',
#     'facebook_use_edge_features': False,
#     'facebook_embedding_ids_path': '',
#     'facebook_edge_feature_columns': '',
#     'facebook_node_features_filename': 'facebook_2022-06-24_2022-06-25_part1_node_features.csv',
#     'not_freeze_learned_label_embedding': False},
#    'trainer_fs': True},
#   'group': None,
#   'jobType': None,
#   'commit': 'b0f14d03e05953bee771cbe1708e44cf2527ae6d',
#   'readOnly': False,
#   'createdAt': '2026-03-07T22:44:18Z',
#   'heartbeatAt': '2026-03-07T22:44:30Z',
#   'description': 'eval_retweet_cls_1hop_07_03_2026_14_42_31',
#   'notes': None,
#   'systemMetrics': {},
#   'summaryMetrics': {'_runtime': 11,
#    '_wandb': {'runtime': 11},
#    'num_params': 1297474,
#    'wandb_url': 'https://wandb.ai/eibl-usc/graph-clip/runs/1ulxsilb'},
#   'historyLineCount': 0,
#   'user': {'name': 'Philipp Eibl', 'username': 'eibl'},
#   'historyKeys': {'keys': {}, 'lastStep': -1, 'sets': []},
#   'rawconfig': {'_wandb': {'e': {'z9hsum8ci6hfc62kgltb4no2ae01p8mz': {'os': 'Linux-4.18.0-553.22.1.el8_10.x86_64-x86_64-with-glibc2.28',
#       'git': {'commit': 'b0f14d03e05953bee771cbe1708e44cf2527ae6d',
#        'remote': 'https://github.com/philippnoah/prodigy.git'},
#       'gpu': 'Tesla P100-PCIE-16GB',
#       'args': ['--dataset',
#        'midterm',
#        '--root',
#        'midterm/graph_retweet',
#        '--input_dim',
#        '98',
#        '--original_features',
#        'True',
#        '--task',
#        'classification',
#        '--n_hop',
#        '1',
#        '--device',
#        '0',
#        '-val_cap',
#        '500',
#        '-test_cap',
#        '500',
#        '--workers',
#        '10',
#        '--eval_only',
#        'True',
#        '--pretrained_model_run',
#        'state/pretrain_retweet_nm_1hop_06_03_2026_19_06_04/state_dict',
#        '--prefix',
#        'eval_retweet_cls_1hop'],
#       'disk': {'/': {'used': '6530154496', 'total': '67519668224'}},
#       'host': 'e21-04.hpc.usc.edu',
#       'root': '/home1/eibl/gfm/prodigy',
#       'email': 'eibl@usc.edu',
#       'slurm': {'conf': '/var/spool/slurm/d/conf-cache/slurm.conf',
#        'gtids': '0',
#        'jobid': '7226495',
#        'umask': '0002',
#        'job_id': '7226495',
#        'nnodes': '1',
#        'nodeid': '0',
#        'nprocs': '1',
#        'ntasks': '1',
#        'procid': '0',
#        'stepid': '0',
#        'job_gid': '98913',
#        'job_qos': 'normal',
#        'job_uid': '606466',
#        'localid': '0',
#        'step_id': '0',
#        'cpu_bind': 'quiet,mask_cpu:0x087FF',
#        'job_name': 'bash',
#        'job_user': 'eibl',
#        'mpi_type': 'pmix_v5',
#        'nodelist': 'e21-04',
#        'pty_port': '34761',
#        'task_pid': '1069723',
#        'job_group': 'eibl',
#        'step_gpus': '0',
#        'submit_dir': '/home1/eibl/gfm/prodigy',
#        'job_account': 'schattop_1481',
#        'pty_win_col': '90',
#        'pty_win_row': '52',
#        'submit_host': 'discovery1.hpc.usc.edu',
#        'cluster_name': 'discovery',
#        'cpus_on_node': '12',
#        'distribution': 'block',
#        'gpus_on_node': '1',
#        'job_end_time': '1772926914',
#        'job_nodelist': 'e21-04',
#        'mem_per_node': '65536',
#        'prio_process': '0',
#        'cpu_bind_list': '0x087FF',
#        'cpu_bind_type': 'mask_cpu:',
#        'cpus_per_task': '12',
#        'job_num_nodes': '1',
#        'job_partition': 'gpu',
#        'oom_kill_step': '0',
#        'step_nodelist': 'e21-04',
#        'topology_addr': 'e21-04',
#        'tres_per_task': 'cpu=12',
#        'job_start_time': '1772923314',
#        'script_context': 'prolog_task',
#        'srun_comm_host': '10.125.0.217',
#        'srun_comm_port': '43165',
#        'step_num_nodes': '1',
#        'step_num_tasks': '1',
#        'tasks_per_node': '1',
#        'cpu_bind_verbose': 'quiet',
#        'job_cpus_per_node': '12',
#        'pmix_mapping_serv': '(vector,(0,1,1))',
#        'launch_node_ipaddr': '10.125.0.217',
#        'step_launcher_port': '43165',
#        'step_tasks_per_node': '1',
#        'topology_addr_pattern': 'node',
#        'pmixp_abort_agent_port': '43185'},
#       'memory': {'total': '135039336448'},
#       'python': 'CPython 3.10.19',
#       'program': '/home1/eibl/gfm/prodigy/experiments/run_single_experiment.py',
#       'codePath': 'experiments/run_single_experiment.py',
#       'writerId': 'z9hsum8ci6hfc62kgltb4no2ae01p8mz',
#       'cpu_count': 20,
#       'gpu_count': 1,
#       'startedAt': '2026-03-07T22:44:15.940874Z',
#       'executable': '/home1/eibl/.conda/envs/prodigy/bin/python',
#       'gpu_nvidia': [{'name': 'Tesla P100-PCIE-16GB',
#         'uuid': 'GPU-766b8c1d-9f1d-56a2-fabc-e09d077324c1',
#         'cudaCores': 3584,
#         'memoryTotal': '17179869184',
#         'architecture': 'Pascal'}],
#       'cudaVersion': '12.9',
#       'codePathLocal': 'experiments/run_single_experiment.py',
#       'cpu_count_logical': 20}},
#     'm': [],
#     't': {'1': [1, 5, 11, 49, 53, 75, 77],
#      '2': [1, 5, 11, 49, 53, 75, 77],
#      '3': [1, 13, 19, 62],
#      '4': '3.10.19',
#      '5': '0.24.2',
#      '6': '4.29.2',
#      '12': '0.24.2',
#      '13': 'linux-x86_64'},
#     'cli_version': '0.24.2',
#     'python_version': '3.10.19'},
#    'params': {'root': 'midterm/graph_retweet',
#     'seed': None,
#     'n_hop': 1,
#     'n_way': 3,
#     'device': 'cuda:0',
#     'epochs': 12,
#     'layers': 'S,U,M',
#     'metric': 'Acc',
#     'prefix': 'eval_retweet_cls_1hop',
#     'dataset': 'midterm',
#     'dropout': 0,
#     'emb_dim': 256,
#     'log_dir': 'log',
#     'n_layer': 1,
#     'n_query': 24,
#     'n_shots': 3,
#     'verbose': False,
#     'workers': 10,
#     'all_test': False,
#     'exp_name': 'eval_retweet_cls_1hop_07_03_2026_14_42_31',
#     'gnn_type': 'sage',
#     'csr_split': False,
#     'eval_only': True,
#     'eval_step': 2000,
#     'input_dim': 98,
#     'label_set': None,
#     'max_users': None,
#     'skip_path': False,
#     'state_dir': 'state',
#     'task_name': 'classification',
#     'timestamp': '07_03_2026_14_42_31',
#     'train_cap': None,
#     'zero_shot': False,
#     'batch_size': 5,
#     'bert_cache': 'multi-qa-distilbert-cos-v1',
#     'calc_ranks': False,
#     'eval_epoch': 10,
#     'label_type': 'verified',
#     'max_length': -1,
#     'print_step': 2000,
#     'second_gnn': 'Atten',
#     'force_cache': False,
#     'n_way_upper': -1,
#     'print_epoch': 10,
#     'val_len_cap': 500,
#     'augment_test': False,
#     'augmentation': '',
#     'csv_filename': 'twitter_data.csv',
#     'kg_emb_model': '',
#     'linear_probe': False,
#     'meta_n_layer': 1,
#     'override_log': False,
#     'test_len_cap': 500,
#     'weight_decay': 0.001,
#     'learning_rate': 0.001,
#     'n_query_upper': -1,
#     'n_shots_upper': -1,
#     'no_bn_encoder': False,
#     'shuffle_index': False,
#     'small_dataset': False,
#     'bert_emb_model': 'multi-qa-distilbert-cos-v1',
#     'has_final_back': False,
#     'checkpoint_step': 2000,
#     'dataset_len_cap': 10000,
#     'experiment_type': 'metagraph',
#     'no_bn_metagraph': False,
#     'no_split_labels': True,
#     'checkpoint_epoch': 10,
#     'invalidate_cache': False,
#     'meta_gnn_pos_only': False,
#     'original_features': True,
#     'reset_after_layer': None,
#     'split_train_nodes': False,
#     'facebook_max_posts': None,
#     'fix_datasets_first': False,
#     'classification_only': False,
#     'facebook_target_dim': 768,
#     'facebook_data_source': 'csv',
#     'pretrained_model_run': 'state/pretrain_retweet_nm_1hop_06_03_2026_19_06_04/state_dict',
#     'attention_mask_scheme': 'causal',
#     'facebook_pkl_filename': 'facebook_2022-06-24_2022-06-25_part1.pkl',
#     'text_features_dropout': 0,
#     'zero_label_embeddings': False,
#     'attr_regression_weight': 0,
#     'rel_sample_random_seed': None,
#     'early_stopping_patience': 20,
#     'facebook_edges_filename': 'facebook_2022-06-24_2022-06-25_part1_edges.csv',
#     'facebook_text_emb_model': '',
#     'ignore_label_embeddings': True,
#     'facebook_embeddings_path': '',
#     'facebook_filter_to_uk_ru': True,
#     'facebook_source_pkl_path': '',
#     'facebook_use_edge_features': False,
#     'facebook_embedding_ids_path': '',
#     'facebook_edge_feature_columns': '',
#     'facebook_node_features_filename': 'facebook_2022-06-24_2022-06-25_part1_node_features.csv',
#     'not_freeze_learned_label_embedding': False},
#    'trainer_fs': True}},
#  'client': <wandb.apis.public.api.RetryingClient at 0x1193e5450>,
#  '_entity': 'eibl-usc',
#  'project': 'graph-clip',
#  '_files': {},
#  '_base_dir': '/var/folders/6w/cs8z0j913k1d_x_ywtvrm5xc0000gp/T',
#  'sweep': None,
#  '_include_sweeps': True,
#  '_lazy': True,
#  '_full_data_loaded': True,
#  'dir': '/var/folders/6w/cs8z0j913k1d_x_ywtvrm5xc0000gp/T/eibl-usc/graph-clip/1ulxsilb',
#  '_summary': {'_runtime': 11, '_wandb': {'runtime': 11}, 'num_params': 1297474, 'wandb_url': 'https://wandb.ai/eibl-usc/graph-clip/runs/1ulxsilb'},
#  '_metadata': None,
#  '_state': 'failed',
#  'server_provides_internal_id_field': None,
#  '_server_provides_project_id_field': True,
#  '_is_loaded': True,
#  '_api': <wandb.apis.public.api.Api at 0x119242800>,
#  '_project_internal_id': 43623038,
#  'user': <User eibl>}

# %%
summary
# Out:
# {'start_test_acc': 0.657264, 'start_test_acc_std': 0.04413980407749903, '_runtime': 357.297702995, '_step': 0, '_timestamp': 1772927413.4086163, '_wandb': {'runtime': 357}, 'num_params': 1297474, 'wandb_url': 'https://wandb.ai/eibl-usc/graph-clip/runs/ks9li9cv'}

# %%
import wandb
import pandas as pd

api = wandb.Api()
runs = api.runs("eibl-usc/graph-clip", filters={"config.params.prefix": {"$regex": "eval_retweet"}})

rows = []
for run in runs:
    row = {
        "n_way": run.config["params"]["n_way"],
        "n_shots": run.config["params"]["n_shots"],
        "n_query": run.config["params"]["n_query"],
        "acc": run.summary.get("start_test_acc"),
        "std": run.summary.get("start_test_acc_std"),
        # "loss": run.summary.get("start_test_loss"),
    }
    rows.append(row)
df = pd.DataFrame(rows)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 13
#       7 rows = []
#       8 for run in runs:
#       9     row = {
#      10         "n_way": run.config["params"]["n_way"],
#      11         "n_shots": run.config["params"]["n_shots"],
#      12         "n_query": run.config["params"]["n_query"],
# ---> 13         "acc": run.summary["start_test_acc"],
#      14         "std": run.summary["start_test_acc_std"],
#      15         # "loss": run.summary["start_test_loss"],
#      16     }
#      17     rows.append(row)
#      18 df = pd.DataFrame(rows)
#
# File ~/miniconda3/envs/prodigy/lib/python3.10/site-packages/wandb/old/summary.py:110, in SummarySubDict.__getitem__(self, k)
#     107     k = k.strip()
#     109 self.get(k)  # load the value into _dict if it should be there
# --> 110 res = self._dict[k]
#     112 return res
#
# KeyError: 'start_test_acc'

# %%
import pandas as pd

# Define the path
path = 'armenia_202012_tweets_io.pkl.gz'

# Load the data
df = pd.read_pickle(path)

# Preview the first few rows
df.head()
# Out:
#                tweetid               userid user_display_name  \
# 0  1331706590525874184  1330897620257136640         Haqqin.az
# 1  1100358276435398656  1098549517299957761    Adem Elekberov
# 2  1100389340914569216  1098613626204753920  Cebrayil Babayev
# 3   724982683118358528   719246221509005313     Zakir Həsənov
# 4   728142042765742080   719246221509005313     Zakir Həsənov
#
#   user_screen_name user_reported_location  \
# 0          Haqqinz             Azerbaijan
# 1    AdemElekberov             Azerbaijan
# 2  CebrayilBabaye1           Agri, Turkey
# 3    zakir_hasanov             Azerbaijan
# 4    zakir_hasanov             Azerbaijan
#
#                             user_profile_description         user_profile_url  \
# 0  https://t.co/7q3bPlI5Ne является независимым и...  https://t.co/TY3gz33nIF
# 1  I’ve learned I don’t know anything.  Have also...                      NaN
# 2  Love the life to its fullest\n#Shareforkhojaly...                      NaN
# 3  Lieutenant General is an Azerbaijani politicia...  https://t.co/06ojhMm2e6
# 4  Lieutenant General is an Azerbaijani politicia...  https://t.co/06ojhMm2e6
#
#    follower_count  following_count account_creation_date  ... retweet_tweetid  \
# 0               0                0            2020-11-23  ...             NaN
# 1             145              530            2019-02-21  ...             NaN
# 2             146              423            2019-02-21  ...             NaN
# 3             112               15            2016-04-10  ...             NaN
# 4             112               15            2016-04-10  ...             NaN
#
#   latitude longitude quote_count reply_count like_count retweet_count  \
# 0   absent    absent           0           0          0             0
# 1   absent    absent           0           0          0             0
# 2   absent    absent           1           0          0             0
# 3   absent    absent           0           0          0             0
# 4   absent    absent           0           0          0             0
#
#                                            hashtags  \
# 0                       [haqqinaz, haqqin, haqqinz]
# 1  [Azerbaijan, shareforkhojaly, justiceforkhojaly]
# 2              [shareforkhojaly, justiceforkhojaly]
# 3                                                []
# 4                                      [Azerbaijan]
#
#                                                 urls user_mentions
# 0                    [https://haqqin.az/news/194712]            []
# 1                                                 []            []
# 2                                                 []            []
# 3  [http://www.unaoc.org/wp-content/uploads/20160...            []
# 4                            [http://bit.ly/24tbEqN]            []
#
# [5 rows x 30 columns]

# %%
df
